# %% [markdown]
# # Individuiamo tre task di qualsiasi tipo (fare la spesa, studiare un concetto, riempire il serbatoio dell'auto,
# # acquistare uno snack da un distributore automatico, o qualunque altra cosa);
# # Scriviamo un algoritmo (in forma testuale), cioè i passi necessari, per ognuno dei task selezionati.
#
# Task 1 - Andare in palestra
# 1. Prendi il borsone
# 2. Esci di casa
# 3. Guida fino alla palestra
# 4. Cambiati i vestiti
# 5. Fai riscaldamento
# 6. Fai gli esercizi
# 7. Fatti la doccia
# 8. Torna a casa
#
# Task 2 - Cucina la pasta
# 1. Prendi una pentola
# 2. Aggiungi dell'acqua
# 3. Metti sul fuoco
# 4. Aggiungi il sale
# 5. Metti il coperchio
# 6. Aspetta che l'acqua bolla
# 7. Butta la pasta
# 8. Controlla il tempo di cottura
# 9. Scola la pasta
# 10. Salta in padella con il condimento.
#
# Task 3 - Guarda un film su Netflix
# 1. Prendi il telecomando
# 2. Accendi la tv
# 3. Seleziona Netflix
# 4. Scegli una categoria
# 5. Seleziona il film da vedere
# 6. Clicca su Play
# 7. Goditi il film

# %%
# Abbiamo 25 studenti; memorizzare questo dato in una variabile.
#Utilizzeremo: • l'operatore di assegnazione = • la funzione print()

studenti = 25
print(studenti)
# Out:
# 25

# %%
# Abbiamo 25 studenti; memorizzare questo dato in una variabile. 
# Arrivano altri 3 studenti; memorizzare questo dato in un'altra variabile. 
# Creare un'altra variabile ancora che conterrà la somma delle prime due, poi stamparla a video. 
# Utilizzeremo: • la funzione print() per stampare a video

studenti = 25
altri_studenti = 3
tot_studenti = studenti + altri_studenti
print(tot_studenti)
# Out:
# 28

# %%
# Creare una variabile che contiene la stringa "Epicode", quindi stamparla a video.

nome = "Epicode"
print(nome)
# Out:
# Epicode

# %%
# Abbiamo la variabile: x = 10 
# Incrementarla di 2 e poi moltiplicarla per 3

x = 10
y = x + 2
z = y * 3
print(z)
# Out:
# 36

# %%
# Alternativa

x  = 10
x = (x + 2) * 3
print(x)
# Out:
# 36

# %%
# Creiamo le seguenti stringhe, e per ognuna di esse verifichiamone la lunghezza con la funzione len(): 
# str1 = "Windows" 
# str2 = "Excel" 
# str3 = "Powerpoint" 
# str4 = "Word"

str1 = "Windows" 
str2 = "Excel" 
str3 = "Powerpoint" 
str4 = "Word"

print(str1, len(str1))
print(str2, len(str2))
print(str3, len(str3))
print(str4, len(str4))
# Out:
# Windows 7
# Excel 5
# Powerpoint 10
# Word 4

# %%
# Calcolare e stampare a video quanti secondi ci sono in un anno non bisestile (365 giorni).

minuto = 60
ora = minuto * 60
giorno = ora * 24
nonbisestile = giorno * 365
print(nonbisestile)
# Out:
# 31536000

# %%
# Abbiamo la seguente stringa: my_string = "I am studying Python" 
my_string = "I am studying Python"

# Trasformarla in modo che tutti i caratteri siano maiuscoli (uppercase) 
my_string.upper()

# Trasformarla in modo che tutti i caratteri siano minuscoli (lowercase) 
my_string.lower()

# Sostituire la sottostringa "Python" con la stringa "a lot" 
my_string.replace("Python", "a lot")

# Usare il metodo .strip(); cambia qualcosa? Perché? 
my_string.strip("Python")  
#strip elimina la parte dentro le (), mentre replace sostituisce una parte dentro (), con una parte che inseriamo noi

# Usare il metodo .split() per trovare tutte le parole (token)
my_string.split(" ")
# Out:
# ['I', 'am', 'studying', 'Python']

# %%
# Abbiamo due liste, una di studenti e una di corsi: 
# studenti = ["Alex", "Bob", "Cindy", "Dan", "Emma", "Faith", "Grace", "Henry"] 
# corsi = ["Cybersecurity", "Data Analyst", "Backend", "Frontend", "Data Analyst", "Backend"]
# Tenendo conto che i dati sono in corrispondenza posizionale, leggiamo con attenzione le due liste. 
# Sapendo che Emma segue Data Analyst 
# Faith segue Backend 
# Grace segue Frontend 
# Henry segue Cybersecurity alla lista cui mancano dei dati, 
# aggiungiamo i dati mancanti uno alla volta con il metodo .append()

studenti = ["Alex", "Bob", "Cindy", "Dan", "Emma", "Faith", "Grace", "Henry"]
corsi = ["Cybersecurity", "Data Analyst", "Backend", "Frontend", "Data Analyst", "Backend"]
corsi.append("Frontend")
corsi.append("Cybersecurity")
print(corsi)
# Out:
# ['Cybersecurity', 'Data Analyst', 'Backend', 'Frontend', 'Data Analyst', 'Backend', 'Frontend', 'Cybersecurity']
